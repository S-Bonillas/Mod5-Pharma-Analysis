# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - On average, tumor volumes are shown to increase in accordance with overall bodymass (weight).  The higher the bodyweight, the greater the volume of tumors.
#
# - Ramicane and Capomulin were the only two treatments to show signs of reducing the volume of tumors, with Ramicane showing the greatest efficacy.
#     - Subjects in the Ramicane and Capomulin regimens had comparatively low starting weights (20g) than the study as a whole (26.1g).
#     - In future tests of Ramicane and Capomulin, subjects with greater bodymass should be utilized to determine if treatment effectiveness is maintained.
#
# - All treatments, aside from Ketapril and Naftisol, appear to have at least slowed the rate of tumor growth. However most of the other treatments were comprable to the placebo.
#     - Under the regimens for Ceftamin, Infubinol, Propriva, Stelasyn, and Zoniferol the rate of tumor growth slowed marginally, but it did not stop.
#
# - Tumor volume growth rates were greater under the Ketapril and Naftisol regimens than with the placebo.
#     - With growing tumor volume, these drugs may not be therapeutically useful, but they might be helpful in isolating other variables which could inform future treatments.
#     - The mice on the Ketapril and Naftisol regimens had notably higher starting bodyweights (27.6g) than the study as a whole (26.1g). The higher bodyweights could indicate more difficult tumors to combat, but that would require further analysis.
#
# - To improve the data gathered by these tests, I would suggest capturing Mouse Weight (g) when Tumor Volume is measured.  This could help show the impact of treatment on the subject over time.
#
# ((Please refer to the 'Additional Tables for Analysis' section for citations.))

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "./Resources/Mouse_metadata.csv"
study_results_path = "./Resources/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
#Reviewing Dataframes
mouse_metadata
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
#Reviewing shows us that the MouseID is the common thread to link these two dataframes.

# Combine the data into a single DataFrame
mouse_study_combined_df = pd.merge(study_results,mouse_metadata, how="left", on="Mouse ID" )

# Display the data table for preview
mouse_study_combined_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
len(mouse_study_combined_df["Mouse ID"].unique())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dupe_mouseid = mouse_study_combined_df[mouse_study_combined_df.duplicated(subset=["Mouse ID", "Timepoint"])]["Mouse ID"].unique()
dupe_mouseid
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dupe_mouseid_dataset = mouse_study_combined_df[mouse_study_combined_df["Mouse ID"] == "g989"]
dupe_mouseid_dataset
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_study_clean_df = mouse_study_combined_df[mouse_study_combined_df["Mouse ID"].isin(dupe_mouseid) == False]
mouse_study_clean_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
len(mouse_study_clean_df["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
tumor_mean = mouse_study_clean_df.groupby("Drug Regimen").mean(numeric_only=True)["Tumor Volume (mm3)"]
tumor_median = mouse_study_clean_df.groupby("Drug Regimen").median(numeric_only=True)["Tumor Volume (mm3)"]
tumor_variance = mouse_study_clean_df.groupby("Drug Regimen").var(numeric_only=True)["Tumor Volume (mm3)"]
tumor_stdev = mouse_study_clean_df.groupby("Drug Regimen").std(numeric_only=True)["Tumor Volume (mm3)"]
tumor_SEM = mouse_study_clean_df.groupby("Drug Regimen").sem(numeric_only=True)["Tumor Volume (mm3)"]

tumor_summary_table = pd.DataFrame({
    "Tumor Volume Mean": tumor_mean,
    "Tumor Volume Median": tumor_median,
    "Tumor  Volume Variance": tumor_variance,
    "Tumor Volume Std. Dev.": tumor_stdev,
    "Tumor Std. Err.": tumor_SEM
})

tumor_summary_table
# Out:
#               Tumor Volume Mean  Tumor Volume Median  Tumor  Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809               24.947764
# Ceftamin              52.591172            51.776157               39.290177
# Infubinol             52.884795            51.820584               43.128684
# Ketapril              55.235638            53.698743               68.553577
# Naftisol              54.331565            52.509285               66.173479
# Placebo               54.033581            52.288934               61.168083
# Propriva              52.320930            50.446266               43.852013
# Ramicane              40.216745            40.673236               23.486704
# Stelasyn              54.233149            52.431737               59.450562
# Zoniferol             53.236507            51.818479               48.533355
#
#               Tumor Volume Std. Dev.  Tumor Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

tumor_summary_table_agg = mouse_study_clean_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean", "median", "var", "std", "sem"]})
tumor_summary_table_agg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
count = mouse_study_clean_df["Drug Regimen"].value_counts()
count.plot(kind="bar")
plt.xlabel("Drug Regimen")
plt.xticks(rotation=45)
plt.ylabel("# of Observed Mouse Timepoints")
plt.show()

# The example showed the xticks with a rotation of 90, but I changed it to 45 because I thought it was more legible.  If the requestor/employer had a specific style guide, I would have abided by that :) .

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

count2 = mouse_study_clean_df["Drug Regimen"].value_counts()
plt.bar(count2.index, count2.values)

plt.xlabel("Drug Regimen")
plt.xticks(rotation=45)
plt.ylabel("# of Observed Mouse Timepoints")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

count3 = mouse_study_clean_df.Sex.value_counts()
count3.plot(kind="pie", autopct="%1.1f%%")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

count4 = mouse_study_clean_df.Sex.value_counts()
plt.pie(count4.values, labels=count4.index.values, autopct="%1.1f%%")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
tumor_max = mouse_study_clean_df.groupby(["Mouse ID"])["Timepoint"].max()
tumor_max = tumor_max.reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
tumor_max_merge = tumor_max.merge(mouse_study_clean_df, on=["Mouse ID", "Timepoint"], how = "left")
tumor_max_merge
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vols = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatment_list:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    treated_tumor_vol = tumor_max_merge.loc[tumor_max_merge["Drug Regimen"] == drug, "Tumor Volume (mm3)"]
    
    # add subset 
    tumor_vols.append(treated_tumor_vol)
    
    # Determine outliers using upper and lower bounds
    quartiles = treated_tumor_vol.quantile([.25, .5, .75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 * iqr)
    
    outliers = treated_tumor_vol.loc[(treated_tumor_vol < lower_bound) | (treated_tumor_vol > upper_bound)]
    
    print(f"{drug}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
orange_out = dict(markerfacecolor="red", markersize=12)
plt.boxplot(tumor_vols, labels = treatment_list, flierprops=orange_out)
plt.ylabel("Final Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
capomulin_table = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] == "Capomulin"]
l509_data = capomulin_table[capomulin_table["Mouse ID"] == "l509"]

plt.plot(l509_data["Timepoint"], l509_data["Tumor Volume (mm3)"])
plt.title("Capomulin Treatment of Mouse L509")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
capomulin_table2 = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] == "Capomulin"]
capomulin_avg = capomulin_table2.groupby(["Mouse ID"]).mean(numeric_only=True)

plt.scatter(capomulin_avg["Weight (g)"], capomulin_avg["Tumor Volume (mm3)"])
plt.title("Mouse Weight vs Observed Tumor Volume (Capomulin)")
plt.xlabel("Weight(g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
correlation = st.pearsonr(capomulin_avg["Weight (g)"], capomulin_avg["Tumor Volume (mm3)"])
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")
      
model = st.linregress(capomulin_avg["Weight (g)"], capomulin_avg["Tumor Volume (mm3)"])
slope = model[0]
b = model[1]
y_values = capomulin_avg["Weight (g)"] * slope + b
plt.scatter(capomulin_avg["Weight (g)"], capomulin_avg["Tumor Volume (mm3)"])
plt.plot(capomulin_avg["Weight (g)"], y_values, color="red")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title("Correlation between Weight and Average Tumor Volume")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84

# %% [markdown]
# ## Additional Tables for Analysis

# %%
# Average Tumor Volume for all Capomulin Treatments Over Time
capomulin_table3 = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] == "Capomulin"]
capomulin_avg_vol = capomulin_table3.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
capomulin_time = capomulin_avg_vol.index

plt.plot(capomulin_time, capomulin_avg_vol, marker='o')
plt.title("Average Tumor Volume Over Time for all Capomulin Treatments")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Average Tumor Volume for all Ramicane Treatments Over Time
ramicane_table = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] == "Ramicane"]
ramicane_avg_vol = ramicane_table.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
ramicane_time = ramicane_avg_vol.index

plt.plot(ramicane_time, ramicane_avg_vol, marker='o')
plt.title("Average Tumor Volume Over Time for all Ramicane Treatments")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Average Tumor Volume for all Infubinol Treatments Over Time
infubinol_table = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] == "Infubinol"]
infubinol_avg_vol = infubinol_table.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
infubinol_time = infubinol_avg_vol.index

plt.plot(infubinol_time, infubinol_avg_vol, marker='o')
plt.title("Average Tumor Volume Over Time for all Infubinol Treatments")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Average Tumor Volume for all Ceftamin Treatments Over Time
ceftamin_table = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] == "Ceftamin"]
ceftamin_avg_vol = ceftamin_table.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
ceftamin_time = ceftamin_avg_vol.index

plt.plot(ceftamin_time, ceftamin_avg_vol, marker='o')
plt.title("Average Tumor Volume Over Time for all Ceftamin Treatments")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Average Tumor Volume for Placebo Over Time
placebo_table = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] == "Placebo"]
placebo_avg_vol = placebo_table.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
placebo_time = placebo_avg_vol.index

plt.plot(placebo_time, placebo_avg_vol, marker='o')
plt.title("Average Tumor Volume Over Time for all Placebo Recipients")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Average Tumor Volume for All Treatments (INCLUDING Placebo) Over Time
all_tumor_vol_avg = mouse_study_clean_df.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
all_tumor_time = all_tumor_vol_avg.index

plt.plot(all_tumor_time, all_tumor_vol_avg, marker='o')
plt.title("Average Tumor Volume Over Time for ALL Treatments (Incl. Placebo)")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Average Tumor Volume for ALL TREATMENTS (EXCLUDING Placebo) Over Time
all_treatments_table = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] != "Placebo"]
all_treatments_avg_vol = all_treatments_table.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
all_treatments_time = all_treatments_avg_vol.index

plt.plot(all_treatments_time, all_treatments_avg_vol, marker='o')
plt.title("Average Tumor Volume Over Time for ALL Treatments (Excl. Placebo)")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Average Tumor Volume for all Capomulin and Ramicane Treatments Over Time
cap_ram_table = mouse_study_clean_df[(mouse_study_clean_df["Drug Regimen"] == "Capomulin") | (mouse_study_clean_df["Drug Regimen"] == "Ramicane")]
cap_ram_avg_vol = cap_ram_table.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
cap_ram_time = cap_ram_avg_vol.index

plt.plot(cap_ram_time, cap_ram_avg_vol, marker='o')
plt.title("Average Tumor Volume Over Time for Capomulin & Ramicane Treatments")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ["Capomulin", "Ceftamin", "Infubinol", "Ketapril", "Naftisol", "Placebo", "Propriva", "Ramicane", "Stelasyn", "Zoniferol"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vols = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatment_list:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    treated_tumor_vol = tumor_max_merge.loc[tumor_max_merge["Drug Regimen"] == drug, "Tumor Volume (mm3)"]
    
    # add subset 
    tumor_vols.append(treated_tumor_vol)
    
    # Determine outliers using upper and lower bounds
    quartiles = treated_tumor_vol.quantile([.25, .5, .75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 * iqr)
    
    outliers = treated_tumor_vol.loc[(treated_tumor_vol < lower_bound) | (treated_tumor_vol > upper_bound)]
    
    print(f"{drug}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ketapril's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Naftisol's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Placebo's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Propriva's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Stelasyn's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Zoniferol's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
orange_out = dict(markerfacecolor="red", markersize=12)
plt.boxplot(tumor_vols, labels = treatment_list, flierprops=orange_out)
plt.ylabel("Final Tumor Volume (mm3)")
plt.xticks(rotation=45)
plt.show()

# %%
# Average Tumor Volume for all Ketapril Treatments Over Time
ketapril_table = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] == "Ketapril"]
ketapril_avg_vol = ketapril_table.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
ketapril_time = ketapril_avg_vol.index

plt.plot(ketapril_time, ketapril_avg_vol, marker='o')
plt.title("Average Tumor Volume Over Time for all Ketapril Treatments")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()

# %%
# Average Tumor Volume for all Ketapril Treatments Over Time
naftisol_table = mouse_study_clean_df[mouse_study_clean_df["Drug Regimen"] == "Naftisol"]
naftisol_avg_vol = naftisol_table.groupby("Timepoint")["Tumor Volume (mm3)"].mean()
naftisol_time = naftisol_avg_vol.index

plt.plot(naftisol_time, naftisol_avg_vol, marker='o')
plt.title("Average Tumor Volume Over Time for all Naftisol Treatments")
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.grid(True)
plt.show()
